# %% [markdown]
# **hf login**

# %% [markdown]
# **install required packages**

# %% [markdown]
# **Declare import**

# %% [markdown]
# **set model and BitsAndBytes config**

# %% [markdown]
# **Set LoRA config**

# %% [markdown]
# **Tokenizer & import model**

# %% [markdown]
# **Import required dataset**

# %% [markdown]
# **pre-pare data for training**

# %% [markdown]
# **set training arg**

# %% [markdown]
# **initialize training**

# %% [markdown]
# **Merge trained model into base model**

# %% [markdown]
# **Test**
